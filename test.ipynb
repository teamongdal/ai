# %%
import pandas as pd

# %%
df = pd.read_csv("product_combined.csv")
df.head()
# Out:
#                                  detail_url                   product_name  \
# 0  https://www.musinsa.com/products/4684399           패딩안감 부클 라운드넥 숏 재킷 블랙
# 1  https://www.musinsa.com/products/3886923  골드 버튼 트위드 재킷 네이비 (324211LY2R)
# 2  https://www.musinsa.com/products/4684396           패딩안감 부클 라운드넥 숏 재킷 애쉬
# 3  https://www.musinsa.com/products/4744793              부클 버클 숏 자켓 스카이 블루
# 4  https://www.musinsa.com/products/4744812          울트윌 패딩안감 숏 자켓 라이트 그레이
#
#   product_price discount_rate final_price brand_name  \
# 0       89,900원             0     89,900원      에잇세컨즈
# 1       89,900원           40%     53,940원      에잇세컨즈
# 2       89,900원             0     89,900원      에잇세컨즈
# 3       89,900원             0     89,900원      에잇세컨즈
# 4       99,900원             0     99,900원      에잇세컨즈
#
#                                          brand_image category category_sub  \
# 0  https://image.musinsa.com/mfile_s01/_brand/fre...      아우터   슈트/블레이저 재킷
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4807 entries, 0 to 4806
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   detail_url        4807 non-null   object
#  1   product_name      4807 non-null   object
#  2   product_price     4807 non-null   object
#  3   discount_rate     4807 non-null   object
#  4   final_price       4807 non-null   object
#  5   brand_name        4807 non-null   object
#  6   brand_image       4807 non-null   object
#  7   category          4807 non-null   object
#  8   category_sub      4806 non-null   object
#  9   product_images_1  4807 non-null   object
#  10  product_images_2  4807 non-null   object
#  11  product_images_3  4807 non-null   object
#  12  product_images_4  4807 non-null   object
#  13  product_code      4807 non-null   object
#  14  heart_cnt         4807 non-null   object
#  15  numof_views       4806 non-null   object
# ...

# %%
df['category'].value_counts()
# Out:
# category
# 상의         3390
# 아우터        1168
# 원피스/스커트     234
# 스포츠/레저       14
# 없음            1
# Name: count, dtype: int64

# %%
df['category_sub'].value_counts()
# Out:
# category_sub
# 반소매 티셔츠       840
# 니트/스웨터        699
# 셔츠/블라우스       650
# 긴소매 티셔츠       554
# 카디건           433
# 맨투맨/스웨트       249
# 슈트/블레이저 재킷    238
# 블루종/MA-1      194
# 피케/카라 티셔츠     158
# 민소매 티셔츠       142
# 미디원피스         130
# 트러커 재킷        112
# 후드 집업         110
# 후드 티셔츠         98
# 미니원피스          74
# 레더/라이더스 재킷     74
# 맥시원피스          30
# 상의              9
# 트레이닝 재킷         7
# 아우터             5
# Name: count, dtype: int64

# %%
len(df['category_sub'].unique())
# Out:
# 21
